# %%
text = """
Результат і рішучість
Енергія, наполегливість, натхнення, цілеспрямованість, дисципліна, розвиток
Жива, насичена, усміхнена
сила, навчання
Продуктивність, знання, енергійність
УКУ, впевненість у собі
успіх
Заряджена енергією на позитив
Аналіз, але цей що Data 😅
Аналіз
успіх!!
Сучасна, програмування, передбачення, драйв, Poland, працьовитість
Захопленість
Смливість і успіх
Смак до життя
Красива
Цілеспрямованість, наполегливість, розвиток, внутрішня сила та краса
Цікава дівчина
Все буде))
Hardkiss
Енергія, сміливість
Цілеспрямованість, життерадісність, енергія
Розвиток і професійність
ІТ, вчителька, вогонь 🔥))
Ефективність, впевненість, професіоналізм
Впевненість, професіоналізм
Успішна, цікава, гарна
Продуктивність
Скілована, послідовна, позитивна
Розум, успіх, енергія
Наполеглива
ML DS work-life-balance
data science machine learning dancing queen
Гармонія, натхнення, успіх
Енергія, успіх, натхнення, цілеспрямованість, всебічність, краса…
Наполегливість, досягнення, DA, ML, справжність
Розвиток, дані, технології, енергія, менторство
впевненість
Sparkling
Нестримна, цілеспрямована, надихаюча
Структура, Впевненість, НатхненняPhD
Енергія, професійність, відкритість, доброзичливість, проф. ріст, допомога
Трудоголік
Професіоналізм, цілеспрямованість, драйв
"""

# %%
import openai
import json
import os
import base64
import requests
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
creds = json.load(open('work/llm-discovery/chatgpt_creds.json'))
openai.api_key = creds['OPENAI_API_KEY']

# %%
wordcloud = WordCloud(width=800, height=400, background_color="white").generate(text)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.savefig('image.png')

# %%
from collections import Counter

# %%
Counter(text.split())
# Out:
# Counter({'Енергія,': 4,
#          'і': 3,
#          'натхнення,': 3,
#          'цілеспрямованість,': 3,
#          'успіх': 3,
#          '1.': 2,
#          '2.': 2,
#          'наполегливість,': 2,
#          '3.': 2,
#          '4.': 2,
#          '5.': 2,
#          '6.': 2,
#          'впевненість': 2,
#          '7.': 2,
#          '8.': 2,
#          '9.': 2,
#          '10.': 2,
#          '11.': 2,
#          '12.': 2,
#          '13.': 2,
#          'Цілеспрямованість,': 2,
#          'енергія': 2,
#          'професіоналізм': 2,
#          'Впевненість,': 2,
#          'успіх,': 2,
#          'Результат': 1,
#          'рішучість': 1,
#          'дисципліна,': 1,
#          'розвиток': 1,
#          'Жива,': 1,
#          'насичена,': 1,
#          'усміхнена': 1,
#          'сила,': 1,
#          'навчання': 1,
#          'Продуктивність,': 1,
#          'знання,': 1,
#          'енергійність': 1,
#          'УКУ,': 1,
#          'у': 1,
#          'собі': 1,
# ...

# %%
# Згрупуємо слова за схожістю
groups = defaultdict(list)

# Вручну згруповані слова
groups['енергія'].extend(['енергія', 'заряджена енергією', 'енергійність'])
groups['впевненість'].extend(['впевненість', 'уверенность'])
groups['успіх'].extend(['успіх', 'успішна'])
groups['цілеспрямованість'].extend(['цілеспрямованість', 'рішучість'])
groups['професіоналізм'].extend(['професіоналізм', 'професійність'])
groups['розвиток'].extend(['розвиток', 'розвиток і професійність', 'розвиток і професіоналізм'])
groups['наполегливість'].extend(['наполегливість'])
groups['продуктивність'].extend(['продуктивність', 'результат', 'ефективність'])
groups['красота'].extend(['краса', 'гарна', 'красива'])
groups['натхнення'].extend(['натхнення'])

# Об'єднати групи в текст
grouped_text = []
for key, words in groups.items():
    grouped_text.append(f"{key} " * len(words))

grouped_text = " ".join(grouped_text)

# Побудова хмари слів для груп
wordcloud = WordCloud(width=800, height=400, background_color="white").generate(grouped_text)

# Візуалізація хмари слів
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# Показати групи
groups
